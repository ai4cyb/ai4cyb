# %% [markdown]
# Project 3: Supervised vs Unsupervised Anomaly Detection
# ===
#
# ___
#
# Submitted by:
#
# * Arthur Humblot
# * Bekhzod Anvarov
# * Ghita El Belghiti
#
# University: Politechnico di Torino
#
# Academic Year: 2025 - 2026

# %% [markdown]
# ## 1. Task 1: Dataset Characterization and Preprocessing

# %% [markdown]
# ## 2. Task 2: Shallow Anomaly Detection - Supervised vs Unsupervised

# %% [markdown]
# ## 3. Task 3: Shallow Anomaly Detection - Supervised vs Unsupervised

# %% [markdown]
# ## 4. Task 4: Unsupervised Anomaly Detection and Interpretation
